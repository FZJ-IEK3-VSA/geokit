# %% [markdown]
# # Create Lines
#
# This example shows to create, visualize and store lines using GeoKit.
#
# ## Import required packages

# %%
import geokit.core.geom
import geokit.core.vector
import geokit.core.srs

# %% [markdown]
# ## Create Lines
#
# Lines can be specified using a list of tuples. A spatial reference system should also be applied, as the coordinates cannot be interpreted without it.

# %%
# Create a LineString geometry from a list of coordinate tuples.

# Define a projection for Aachen area
aachen_centered_srs = geokit.core.srs.centeredLAEA(6.083, 50.775)

# Create a linestring geometry using a list of xy-coordinate tuples
house_line = geokit.core.geom.line(
    [
        (0, 0),
        (40000, 0),
        (40000, 30000),
        (20000, 50000),
        (0, 30000),
        (0, 0),
    ],
    srs=aachen_centered_srs,
)

print(type(house_line))

# %% [markdown]
# ## Visualize Line

# %%
ax_handle = geokit.core.geom.drawGeoms(
    geoms=house_line,
    figsize=(4, 4),
    srs=aachen_centered_srs,
)

# %% [markdown]
# ## Store Line as Vector File

# %%
# Simple vector creation
geokit.core.vector.createVector(geoms=house_line, output="example_lines.shp")
