# %% [markdown]
# # GeoPackages
#
# A GeoPackage is a vector data format designed to store geospatial data in a single file.
# Unlike Shapefiles, all geometries, attributes, and spatial reference information are stored together in one file with the extension `.gpkg`.
#
# A GeoPackage can contain multiple vector layers, making it suitable for more complex datasets and workflows.
#
# **Key characteristics**
#
# - Stored as a single `.gpkg` file
# - Can contain multiple vector layers
# - Supports different geometry types and complex attributes
# - Stores coordinate reference system (CRS) information internally
#
# When working with GeoPackages in GeoKit, a specific layer can be selected if the file contains more than one layer.

# %% [markdown]
# **Import required packages**
#
# GeoKit is imported to provide the required functionality for working with vector data.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pathlib
import geokit.core.vector
import geokit.core.geom
from geokit.core.get_test_data import get_test_data

# %%
# Path to gpkg folder
# Path to cache folder
data_cache_folder = pathlib.Path().cwd().parent.parent.joinpath("geokit", "data")
gadm36_NLD_path = get_test_data(
    file_name="gadm36_NLD.gpkg",
    data_cache_folder=data_cache_folder,
)
# Load vector dataset from a gpgk file for a specific layer
netherland_vector = geokit.core.vector.extractFeatures(source=gadm36_NLD_path)

# show dataset
netherland_vector
# Out:
#                                                   geom GID_0       NAME_0  \
# 0    MULTIPOLYGON (((6.94647121429443 52.9936218261...   NLD  Netherlands
# 1    MULTIPOLYGON (((6.56990480422985 52.9465103149...   NLD  Netherlands
# 2    MULTIPOLYGON (((7.02171897888195 52.8720512390...   NLD  Netherlands
# 3    MULTIPOLYGON (((6.81630086898815 52.6486167907...   NLD  Netherlands
# 4    MULTIPOLYGON (((6.45566606521606 52.7859497070...   NLD  Netherlands
# ..                                                 ...   ...          ...
# 486  MULTIPOLYGON (((5.03120088577276 51.8827285766...   NLD  Netherlands
# 487  MULTIPOLYGON (((4.60047912597656 51.9881019592...   NLD  Netherlands
# 488  MULTIPOLYGON (((4.50599479675293 52.0322647094...   NLD  Netherlands
# 489  MULTIPOLYGON (((4.53282308578503 52.0800552368...   NLD  Netherlands
# 490  MULTIPOLYGON (((4.55539989471441 51.8306732177...   NLD  Netherlands
#
#         GID_1        NAME_1 NL_NAME_1        GID_2                   NAME_2  \
# 0     NLD.1_1       Drenthe      None    NLD.1.1_1              Aa en Hunze
# 1     NLD.1_1       Drenthe      None    NLD.1.2_1                    Assen
# 2     NLD.1_1       Drenthe      None    NLD.1.3_1            Borger-Odoorn
# 3     NLD.1_1       Drenthe      None    NLD.1.4_1                Coevorden
# 4     NLD.1_1       Drenthe      None    NLD.1.5_1                De Wolden
# ..        ...           ...       ...          ...                      ...
# 486  NLD.14_1  Zuid-Holland      None  NLD.14.87_1                  Zederik
# 487  NLD.14_1  Zuid-Holland      None  NLD.14.88_1  Zevenhuizen-Moerkapelle
# 488  NLD.14_1  Zuid-Holland      None  NLD.14.89_1               Zoetermeer
# 489  NLD.14_1  Zuid-Holland      None  NLD.14.90_1              Zoeterwoude
# 490  NLD.14_1  Zuid-Holland      None  NLD.14.91_1              Zwijndrecht
#
#     VARNAME_2 NL_NAME_2    TYPE_2     ENGTYPE_2  CC_2    HASC_2
# 0        None      None  Gemeente  Municipality  None  NL.DR.AH
# 1        None      None  Gemeente  Municipality  None  NL.DR.AS
# 2        None      None  Gemeente  Municipality  None  NL.DR.BO
# 3        None      None  Gemeente  Municipality  None  NL.DR.CO
# 4        None      None  Gemeente  Municipality  None  NL.DR.DW
# ..        ...       ...       ...           ...   ...       ...
# 486      None      None  Gemeente  Municipality  None  NL.ZH.ZE
# 487      None      None  Gemeente  Municipality  None  NL.ZH.ZM
# 488      None      None  Gemeente  Municipality  None  NL.ZH.ZR
# 489      None      None  Gemeente  Municipality  None  NL.ZH.ZD
# 490      None      None  Gemeente  Municipality  None  NL.ZH.ZW
#
# [491 rows x 14 columns]

# %%
ax_handles = geokit.core.geom.drawGeoms(netherland_vector)

# %% [markdown]
# ### Analylze vector data

# %%
vinfo = geokit.core.vector.vectorInfo(gadm36_NLD_path)

# show information about the vector dataset
print("COUNT", vinfo.count)

print("SRS", vinfo.srs)

print("ATTRIBUTES", vinfo.attributes)
# Out:
# COUNT 491
# SRS GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# ATTRIBUTES ['GID_0', 'NAME_0', 'GID_1', 'NAME_1', 'NL_NAME_1', 'GID_2', 'NAME_2', 'VARNAME_2', 'NL_NAME_2', 'TYPE_2', 'ENGTYPE_2', 'CC_2', 'HASC_2']
