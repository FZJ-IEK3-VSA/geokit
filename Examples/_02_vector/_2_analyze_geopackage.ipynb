# %% [markdown]
# # Inspect GeoPackages (.gpkg)
#
# A GeoPackage is a vector data format designed to store geospatial data in a single file.
# Unlike Shapefiles, all geometries, attributes, and spatial reference information are stored together in one file with the extension `.gpkg`.
#
# A GeoPackage can contain multiple vector layers, making it suitable for more complex datasets and workflows.
#
# **Key characteristics**
#
# - Stored as a single `.gpkg` file
# - Can contain multiple vector layers
# - Supports different geometry types and complex attributes
# - Stores coordinate reference system (CRS) information internally
#
# When working with GeoPackages in GeoKit, a specific layer can be selected if the file contains more than one layer.

# %% [markdown]
# **Import required packages**
#
# GeoKit is imported to provide the required functionality for working with vector data.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pathlib
import geokit.core.vector
import geokit.core.geom
from geokit.core.get_test_data import get_test_data

# %%
# Path to cache folder
data_cache_folder = pathlib.Path().cwd().parent.parent.joinpath("geokit", "data")
# Path to gpkg folder
gadm36_NLD_path = get_test_data(
    file_name="gadm36_NLD.gpkg",
    data_cache_folder=data_cache_folder,
)
# Get the names of the vector layers in the gpkg file
list_of_vector_layer = geokit.core.vector.listLayers(gadm36_NLD_path)
print(list_of_vector_layer)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[2], line 4
#       2 data_cache_folder = pathlib.Path().cwd().parent.parent.joinpath("geokit", "data")
#       3 # Path to gpkg folder
# ----> 4 gadm36_NLD_path = get_test_data(
#       5     file_name="gadm36_NLD.gpkg",
#       6     data_cache_folder=data_cache_folder,
#       7 )
#       8 # Get the names of the vector layers in the gpkg file
#       9 list_of_vector_layer = geokit.core.vector.listLayers(gadm36_NLD_path)
#
# File ~/.conda/envs/geokit_env_hack/lib/python3.13/site-packages/geokit/core/get_test_data.py:160, in get_test_data(file_name, data_cache_folder, no_download)
#     154 def get_test_data(
#     155     file_name: str,
#     156     data_cache_folder: pathlib.Path = pathlib.Path(__file__).parent.parent.joinpath("data"),
#     157     no_download: bool = True,
#     158 ) -> str:
#     159     if file_name not in all_file_name_dict:
# --> 160         raise Exception(
#     161             "The requested file,"
#     162             + str(file_name)
#     163             + " , is not included in the test and example data dictionary. Perhaps it's a typo? The following files can be retrieved from the test and example data dictionary: \n\n"
#     164             + str(list(all_file_name_dict.keys()))
#     165         )
#     166     file_extension = pathlib.Path(file_name).suffix
#     167     file_name = pathlib.Path(file_name).name
#
# Exception: The requested file,gadm36_NLD.gpkg , is not included in the test and example data dictionary. Perhaps it's a typo? The following files can be retrieved from the test and example data dictionary:
#
# ['aachenShapefile.dbf', 'aachenShapefile.prj', 'aachenShapefile.qpj', 'aachenShapefile.shp', 'aachenShapefile.shx', 'aachen_buildings.dbf', 'aachen_buildings.prj', 'aachen_buildings.qpj', 'aachen_buildings.shp', 'aachen_buildings.shx', 'aachen_eligibility.tif', 'aachen_points.dbf', 'aachen_points.prj', 'aachen_points.qpj', 'aachen_points.shp', 'aachen_points.shx', 'aachen_rails.dbf', 'aachen_rails.prj', 'aachen_rails.qpj', 'aachen_rails.shp', 'aachen_rails.shx', 'aachen_zones.cpg', 'aachen_zones.dbf', 'aachen_zones.prj', 'aachen_zones.qpj', 'aachen_zones.shp', 'aachen_zones.shx', 'boxes.dbf', 'boxes.prj', 'boxes.shp', 'boxes.shx', 'CDDA_aachenClipped.dbf', 'CDDA_aachenClipped.prj', 'CDDA_aachenClipped.qpj', 'CDDA_aachenClipped.shp', 'CDDA_aachenClipped.shx', 'clc-aachen_clipped-unflipped.tif', 'clc-aachen_clipped.tif', 'clippedCLC.tif', 'divided_raster_1.tif', 'divided_raster_2.tif', 'divided_raster_3.tif', 'elevation.tif', 'elevation_singleHill.tif', 'Europe_with_H2MobilityData_GermanyClip.dbf', 'Europe_with_H2MobilityData_GermanyClip.prj', 'Europe_with_H2MobilityData_GermanyClip.qpj', 'Europe_with_H2MobilityData_GermanyClip.shp', 'Europe_with_H2MobilityData_GermanyClip.shx', 'FJI.dbf', 'FJI.prj', 'FJI.shp', 'FJI.shx', 'gadm36_DEU_1.cpg', 'gadm36_DEU_1.dbf', 'gadm36_DEU_1.prj', 'gadm36_DEU_1.shp', 'gadm36_DEU_1.shx', 'gsa-ghi-like.tif', 'LuxLines.dbf', 'LuxLines.prj', 'LuxLines.qpj', 'LuxLines.shp', 'LuxLines.shx', 'LuxShape.dbf', 'LuxShape.prj', 'LuxShape.qpj', 'LuxShape.shp', 'LuxShape.shx', 'multiFeature.cpg', 'multiFeature.dbf', 'multiFeature.prj', 'multiFeature.qpj', 'multiFeature.shp', 'multiFeature.shx', 'Natura2000_aachenClipped.dbf', 'Natura2000_aachenClipped.prj', 'Natura2000_aachenClipped.qpj', 'Natura2000_aachenClipped.shp', 'Natura2000_aachenClipped.shx', 'raster_gdal_244.tif', 'surroundingRaster.tif', 'turbinePlacements.dbf', 'turbinePlacements.prj', 'turbinePlacements.shp', 'turbinePlacements.shx', 'urban_land_cover_aachenClipped.tif', 'osm_roads_minor.9.264.171.tif', 'osm_roads_minor.9.264.172.tif', 'osm_roads_minor.9.265.171.tif', 'osm_roads_minor.9.265.172.tif', 'test_raster_3x3.tif']

# %%
# Load vector dataset from a gpgk file for a specific layer
netherland_vector_0 = geokit.core.vector.extractFeatures(source=gadm36_NLD_path, layerName="gadm36_NLD_0")

# Load vector dataset from a gpgk file for a specific layer
netherland_vector_1 = geokit.core.vector.extractFeatures(source=gadm36_NLD_path, layerName="gadm36_NLD_1")
# Load vector dataset from a gpgk file for a specific layer
netherland_vector_2 = geokit.core.vector.extractFeatures(source=gadm36_NLD_path, layerName="gadm36_NLD_2")

netherland_vector_complete = geokit.core.vector.extractFeatures(source=gadm36_NLD_path)

# %%
fig,axs=plt.subplots(nrows=2, ncols=2, figsize=(10, 8))
ax_handles = geokit.core.geom.drawGeoms(geoms=netherland_vector_0,ax=axs[0,0])
ax_handles = geokit.core.geom.drawGeoms(geoms=netherland_vector_1,ax=axs[0,1])
ax_handles = geokit.core.geom.drawGeoms(geoms=netherland_vector_2, ax=axs[1,0])
ax_handles = geokit.core.geom.drawGeoms(geoms=netherland_vector_complete, ax=axs[1,1])

# %% [markdown]
# ### Analylze vector data

# %%
vinfo = geokit.core.vector.vectorInfo(gadm36_NLD_path)

# show information about the vector dataset
print("COUNT", vinfo.count)

print("SRS", vinfo.srs)

print("ATTRIBUTES", vinfo.attributes)
